# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelBFG/cnn-based-autoencoder/blob/master/ridge_function_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def f(x, y):
  return 1/(1+np.exp(-x))
  # return np.exp(-0.5*x**2)
  # return np.exp(-0.5*np.power(np.dot(v, vars)),2)

x = np.linspace(-4, 4, 30)
y = np.linspace(-4, 4, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.axes(projection='3d')
# ax.contour3D(X, Y, Z, 100, cmap='binary')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
ax.set_zlabel('z');
plt.title('Sigmoide')
plt.show()

# %%
ax.view_init(20, 80)
fig
